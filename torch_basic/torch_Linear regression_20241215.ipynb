# %%
import torch
import matplotlib.pyplot as plt

x = torch.tensor([150, 160, 170, 175, 185.]) # 키
y = torch.tensor([55, 70, 64, 80, 75.]) # 몸무게
N = len(x)
plt.plot(x,y,'o')

# %%
# 초깃값 설정
a = 0.45
b = -35
x_plot=torch.linspace(145,190,100)
y_plot=a * x_plot + b

plt.plot(x,y,'o')
plt.plot(x_plot,y_plot,'r')

# %%
# a,b 를 바꿔가면서 Loss 값을 일일히 구해서 가장 작아지게 하는 a,b를 선정

a = 0.5 + torch.linspace(-0.2,0.2,100)
b = -30 + torch.linspace(-20,20,100)

L=torch.zeros(len(b),len(a))
for i in range(len(b)):
    for j in range(len(a)):
        for n in range(N):
            L[i,j] = L[i,j] + (y[n] - (a[j]*x[n]+b[i]))**2
L = L/N # MSE

plt.figure(figsize=[10, 9])
ax = plt.axes(projection="3d")
A, B = torch.meshgrid(a,b)
ax.plot_surface(A,B,L);
ax.set_xlabel('a'); ax.set_ylabel('b')
ax.set_zlim([0, 1000])

plt.figure()
plt.contour(a,b,L,30)
plt.xlabel('a'); plt.ylabel('b'); plt.grid()

# %%
print(torch.min(L))
a_opt = A[L==torch.min(L)]
b_opt = B[L==torch.min(L)]
print(f"optimal a = {a_opt}")
print(f"optimal b = {b_opt}")
# Out:
# tensor(29.0315)
# optimal a = tensor([0.5424])
# optimal b = tensor([-23.7374])

# %%
x_plot=torch.linspace(145,190,100)
y_plot=a_opt * x_plot + b_opt
plt.plot(x,y,'o')
plt.plot(x_plot,y_plot,'r')

# %%
import plotly.graph_objects as go
fig = go.Figure(data=[go.Surface(x=a, y=b, z=L, colorscale="viridis", opacity=0.5)])
fig.update_traces(contours_z=dict(show=True, usecolormap=True, highlightcolor="limegreen", project_z=True))
fig.update_layout(title='Loss', width=700, height=600,
                  scene = dict( zaxis=dict(nticks=20, range=[0,1000]) ))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7c84fc4e-632d-4f95-8985-17ca404a7c27" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c84fc4e-632d-4f95-8985-17ca404a7c27")) {                    Plotly.newPlot(                        "7c84fc4e-632d-4f95-8985-17ca404a7c27",                        [{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"opacity":0.5,"x":[0.30000001192092896,0.30404040217399597,0.308080792427063,0.3121212124824524,0.3161616325378418,0.3202020227909088,0.32424241304397583,0.32828283309936523,0.33232322335243225,0.33636361360549927,0.34040403366088867,0.3444444537162781,0.3484848439693451,0.3525252342224121,0.3565656542778015,0.3606060743331909,0.36464646458625793,0.36868685483932495,0.37272727489471436,0.37676769495010376,0.3808080852031708,0.3848484754562378,0.3888888955116272,0.3929292857646942,0.3969697058200836,0.40101009607315063,0.40505051612854004,0.40909090638160706,0.4131312966346741,0.4171717166900635,0.4212121367454529,0.4252525269985199,0.4292929172515869,0.4333333373069763,0.4373737573623657,0.44141414761543274,0.44545453786849976,0.44949495792388916,0.4535353481769562,0.4575757682323456,0.4616161584854126,0.465656578540802,0.469696968793869,0.4737373888492584,0.47777777910232544,0.48181819915771484,0.48585858941078186,0.48989900946617126,0.4939393997192383,0.4979797899723053,0.5020201802253723,0.5060606002807617,0.5101010203361511,0.5141413807868958,0.5181818008422852,0.5222222208976746,0.526262640953064,0.5303030014038086,0.534343421459198,0.5383838415145874,0.5424242615699768,0.5464646220207214,0.5505050420761108,0.5545454621315002,0.5585858821868896,0.5626262426376343,0.5666666626930237,0.5707070827484131,0.5747474431991577,0.5787878632545471,0.5828282833099365,0.5868687033653259,0.5909090638160706,0.59494948387146,0.5989899039268494,0.6030303239822388,0.6070706844329834,0.6111111044883728,0.6151515245437622,0.6191918849945068,0.6232323050498962,0.6272727251052856,0.631313145160675,0.6353535652160645,0.6393939256668091,0.6434343457221985,0.6474747657775879,0.6515151262283325,0.6555555462837219,0.6595959663391113,0.6636363863945007,0.6676768064498901,0.6717171669006348,0.6757575869560242,0.6797980070114136,0.6838383674621582,0.6878787875175476,0.691919207572937,0.6959595680236816,0.699999988079071],"y":[-50.0,-49.5959587097168,-49.191917419433594,-48.787879943847656,-48.38383865356445,-47.97979736328125,-47.57575988769531,-47.171714782714844,-46.767677307128906,-46.3636360168457,-45.9595947265625,-45.55555725097656,-45.15151596069336,-44.747474670410156,-44.34343338012695,-43.93939208984375,-43.53535461425781,-43.13131332397461,-42.727272033691406,-42.32323455810547,-41.919193267822266,-41.51515197753906,-41.11111068725586,-40.707069396972656,-40.30303192138672,-39.898990631103516,-39.49494934082031,-39.09090805053711,-38.686866760253906,-38.28282928466797,-37.878787994384766,-37.47474670410156,-37.070709228515625,-36.66666793823242,-36.26262664794922,-35.858585357666016,-35.45454406738281,-35.050506591796875,-34.64646530151367,-34.24242401123047,-33.838382720947266,-33.43434524536133,-33.030303955078125,-32.62626266479492,-32.22222137451172,-31.81818199157715,-31.414142608642578,-31.010101318359375,-30.606060028076172,-30.2020206451416,-29.7979793548584,-29.393939971923828,-28.989898681640625,-28.585857391357422,-28.18181800842285,-27.77777671813965,-27.373737335205078,-26.969696044921875,-26.565656661987305,-26.1616153717041,-25.75757598876953,-25.353534698486328,-24.94949531555175 ...

# %%
# 모델 파라미터 초기화
a = torch.tensor([0.45], requires_grad=True)
b = torch.tensor([-35.], requires_grad=True)

# 하이퍼파라미터 설정
LR = 3e-6
EPOCH = 20

loss_history = []

for ep in range(EPOCH):
    # inference
    y_hat = a * x + b
    # loss
    loss = 0
    for n in range(N):
        loss += (y[n] - y_hat[n])**2
    loss = loss/N # MSE
    # update
    loss.backward() # backpropagation
    with torch.no_grad():
        a -= LR * a.grad # weight update
        b -= LR * b.grad # weight update
    a.grad = torch.tensor([0.]) # gradient 초기화
    b.grad = torch.tensor([0.]) # gradient 초기화
    # print loss
    loss_history += [loss.item()]
    print(f"Epoch: {ep+1}, train loss: {loss.item():.4f}")
    # print weight and bias
    print(f"Weight: {a.item():.4f}, Bias: {b.item():.4f}")
    # plot graph
    x_plot = torch.linspace(145, 190, 100)
    y_plot = a.detach() * x_plot + b.detach()
    plt.figure()
    plt.plot(x, y, 'o')
    plt.plot(x_plot, y_plot, 'r')
    plt.title(f"Epoch {ep+1}")
    plt.show()

    print("-"*20)
# Out:
# Epoch: 1, train loss: 826.2250
# Weight: 0.4785, Bias: -34.9998
# --------------------
# Epoch: 2, train loss: 578.0414
# Weight: 0.5022, Bias: -34.9997
# --------------------
# Epoch: 3, train loss: 407.1602
# Weight: 0.5218, Bias: -34.9996
# --------------------
# Epoch: 4, train loss: 289.5042
# Weight: 0.5381, Bias: -34.9995
# --------------------
# Epoch: 5, train loss: 208.4954
# Weight: 0.5517, Bias: -34.9994
# --------------------
# Epoch: 6, train loss: 152.7187
# Weight: 0.5629, Bias: -34.9993
# --------------------
# Epoch: 7, train loss: 114.3153
# Weight: 0.5722, Bias: -34.9993
# --------------------
# Epoch: 8, train loss: 87.8735
# Weight: 0.5799, Bias: -34.9992
# --------------------
# Epoch: 9, train loss: 69.6676
# Weight: 0.5863, Bias: -34.9992
# --------------------
# Epoch: 10, train loss: 57.1324
# Weight: 0.5917, Bias: -34.9992
# --------------------
# Epoch: 11, train loss: 48.5017
# Weight: 0.5961, Bias: -34.9991
# --------------------
# Epoch: 12, train loss: 42.5591
# Weight: 0.5997, Bias: -34.9991
# --------------------
# Epoch: 13, train loss: 38.4676
# Weight: 0.6028, Bias: -34.9991
# --------------------
# Epoch: 14, train loss: 35.6504
# Weight: 0.6053, Bias: -34.9991
# --------------------
# Epoch: 15, train loss: 33.7107
# Weight: 0.6074, Bias: -34.9991
# --------------------
# Epoch: 16, train loss: 32.3752
# Weight: 0.6091, Bias: -34.9991
# --------------------
# Epoch: 17, train loss: 31.4557
# Weight: 0.6106, Bias: -34.9990
# --------------------
# Epoch: 18, train loss: 30.8226
# Weight: 0.6118, Bias: -34.9990
# --------------------
# Epoch: 19, train loss: 30.3866
# Weight: 0.6127, Bias: -34.9990
# --------------------
# Epoch: 20, train loss: 30.0865
# Weight: 0.6136, Bias: -34.9990
# --------------------

# %%
# .grad 초기화 필요한 이유 실험
z = torch.tensor([1.],requires_grad=True)
for _ in range(2):
    loss = z**2
    loss.backward()
    print(z.grad)
    # z.grad = torch.tensor([0.])
    # print(z.grad)
# Out:
# tensor([2.])
# tensor([4.])

# %%
# plot loss_history
plt.plot(range(1, EPOCH+1), loss_history)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss")
# Out:
# Text(0.5, 1.0, 'Training Loss')

# %%
from torch import nn, optim

x=x.reshape(-1,1) # 개채 형태로 바꿔줌

model=nn.Linear(1,1)
model.weight.data = torch.tensor([[0.45]])
model.bias.data = torch.tensor([-35.])

LR = 3e-6
EPOCH = 20
optimizer = optim.SGD(model.parameters(), lr=LR)
criterion = nn.MSELoss()

loss_history=[]

for ep in range(EPOCH):
    # inference
    y_hat = model(x)
    # loss
    loss = criterion(y_hat,y)
    # update
    optimizer.zero_grad() # gradient 누적을 막기 위한 초기화
    loss.backward() # backpropagation
    optimizer.step() # weight update
    # print loss
    loss_history += [loss.item()]
    print(f"Epoch: {ep+1}, train loss: {loss.item():.4f}")
    # print weight and bias
    print(f"Weight: {model.weight.data.item():.4f}, Bias: {model.bias.data.item():.4f}")
    # plot graph
    x_plot=torch.linspace(145,190,100)
    y_plot=model.weight.squeeze().detach() * x_plot + model.bias.detach()
    plt.figure()
    plt.plot(x,y,'o')
    plt.plot(x_plot,y_plot,'r')
    plt.title(f"Epoch {ep+1}")
    plt.show()

    print("-"*20)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:538: UserWarning:
#
# Using a target size (torch.Size([5])) that is different to the input size (torch.Size([5, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
# Epoch: 1, train loss: 900.5650
# Weight: 0.4780, Bias: -34.9998
# --------------------
# Epoch: 2, train loss: 660.9294
# Weight: 0.5013, Bias: -34.9997
# --------------------
# Epoch: 3, train loss: 495.9343
# Weight: 0.5206, Bias: -34.9996
# --------------------
# Epoch: 4, train loss: 382.3307
# Weight: 0.5366, Bias: -34.9995
# --------------------
# Epoch: 5, train loss: 304.1121
# Weight: 0.5499, Bias: -34.9994
# --------------------
# Epoch: 6, train loss: 250.2566
# Weight: 0.5609, Bias: -34.9993
# --------------------
# Epoch: 7, train loss: 213.1756
# Weight: 0.5701, Bias: -34.9993
# --------------------
# Epoch: 8, train loss: 187.6445
# Weight: 0.5777, Bias: -34.9992
# --------------------
# Epoch: 9, train loss: 170.0657
# Weight: 0.5840, Bias: -34.9992
# --------------------
# Epoch: 10, train loss: 157.9622
# Weight: 0.5892, Bias: -34.9991
# --------------------
# Epoch: 11, train loss: 149.6288
# Weight: 0.5935, Bias: -34.9991
# --------------------
# Epoch: 12, train loss: 143.8909
# Weight: 0.5971, Bias: -34.9991
# --------------------
# Epoch: 13, train loss: 139.9402
# Weight: 0.6001, Bias: -34.9991
# --------------------
# Epoch: 14, train loss: 137.2202
# Weight: 0.6026, Bias: -34.9991
# --------------------
# Epoch: 15, train loss: 135.3472
# Weight: 0.6046, Bias: -34.9990
# --------------------
# Epoch: 16, train loss: 134.0578
# Weight: 0.6064, Bias: -34.9990
# --------------------
# Epoch: 17, train loss: 133.1698
# Weight: 0.6078, Bias: -34.9990
# --------------------
# Epoch: 18, train loss: 132.5586
# Weight: 0.6089, Bias: -34.9990
# --------------------
# Epoch: 19, train loss: 132.1376
# Weight: 0.6099, Bias: -34.9990
# --------------------
# Epoch: 20, train loss: 131.8478
# Weight: 0.6107, Bias: -34.9990
# --------------------

# %%
# plot loss_history
plt.plot(range(1, EPOCH+1), loss_history)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss")
# Out:
# Text(0.5, 1.0, 'Training Loss')
